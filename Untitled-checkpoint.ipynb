# %% [markdown]
# # Automação de Processos com Python

# %% [markdown]
# ## Problema a ser resolvido passo-a-passo

# %% [markdown]
# ## Buscar automaticamente os dados das ações

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ea\anaconda3\lib\site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ea\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ea\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\ea\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ea\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ea\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ea\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ea\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ea\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ea\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ea\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ea\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ea\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ea\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ea\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ea\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\ea\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import yfinance
import matplotlib.pyplot as plt

codigo = input("Digite o código da ação desejada:  ") 
dados = yfinance.Ticker(codigo).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite o código da ação desejada:  BBAS3.SA
# <Axes: xlabel='Date'>

# %%
dados
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-07-26 00:00:00-03:00  28.710424  28.960885  28.413578  28.756805
# 2023-07-27 00:00:00-03:00  28.617661  28.654766  27.254031  27.263308
# 2023-07-28 00:00:00-03:00  27.300412  27.782785  27.198371  27.606533
# 2023-07-31 00:00:00-03:00  28.107458  28.895951  28.107458  28.858847
# 2023-08-01 00:00:00-03:00  28.840295  28.840295  27.782787  28.385752
# ...                              ...        ...        ...        ...
# 2024-01-22 00:00:00-03:00  37.500000  37.810001  37.230000  37.700001
# 2024-01-23 00:00:00-03:00  37.840000  38.369999  37.430000  38.169998
# 2024-01-24 00:00:00-03:00  38.290001  38.540001  37.770000  37.880001
# 2024-01-25 00:00:00-03:00  38.259998  39.279999  38.130001  39.279999
# 2024-01-26 00:00:00-03:00  39.099998  40.090000  38.910000  39.959999
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-07-26 00:00:00-03:00  45880200        0.0           0.0
# 2023-07-27 00:00:00-03:00  86471900        0.0           0.0
# 2023-07-28 00:00:00-03:00  43608600        0.0           0.0
# 2023-07-31 00:00:00-03:00  91290800        0.0           0.0
# 2023-08-01 00:00:00-03:00  75752400        0.0           0.0
# ...                             ...        ...           ...
# 2024-01-22 00:00:00-03:00  22753700        0.0           0.0
# 2024-01-23 00:00:00-03:00  32498500        0.0           0.0
# 2024-01-24 00:00:00-03:00  25415300        0.0           0.0
# 2024-01-25 00:00:00-03:00  48655300        0.0           0.0
# 2024-01-26 00:00:00-03:00  41378200        0.0           0.0
#
# [126 rows x 7 columns]

# %%
fechamento
# Out:
# Date
# 2023-07-26 00:00:00-03:00    46.331783
# 2023-07-27 00:00:00-03:00    45.380295
# 2023-07-28 00:00:00-03:00    45.904579
# 2023-07-31 00:00:00-03:00    46.788109
# 2023-08-01 00:00:00-03:00    45.982254
#                                ...
# 2024-01-22 00:00:00-03:00    55.549999
# 2024-01-23 00:00:00-03:00    56.540001
# 2024-01-24 00:00:00-03:00    56.650002
# 2024-01-25 00:00:00-03:00    56.580002
# 2024-01-26 00:00:00-03:00    56.970001
# Name: Close, Length: 126, dtype: float64

# %% [markdown]
# # Gerar as análises de forma automática
#
#
# ## Passo 2 -
#
# - Análise dos últimos 6 meses
# - Cotação máxima
# - Cotação miníma
# - Cotação atual

# %%
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]

# %% [markdown]
# # Enviar um e-mail para o nosso Gestor
#
# ## Passo 3-
#
# - abrir uma nova aba no navegador (ctrl + t)
# - digitar o endereço do gmail e dar um enter
# - clicar no botão escrever
# - colocar e-mail do destinatário (tab)
# - colocar o assunto (tab)
# - corpo do e-mail
# - clicar no botão enviar

# %%
# !pip install pyautogui
# Out:
# Collecting pyautogui
#   Using cached PyAutoGUI-0.9.54-py3-none-any.whl
# Collecting pymsgbox (from pyautogui)
#   Using cached PyMsgBox-1.0.9-py3-none-any.whl
# Collecting pytweening>=1.0.4 (from pyautogui)
#   Using cached pytweening-1.0.7-py3-none-any.whl
# Collecting pyscreeze>=0.1.21 (from pyautogui)
#   Using cached PyScreeze-0.1.30-py3-none-any.whl
# Collecting pygetwindow>=0.0.5 (from pyautogui)
#   Using cached PyGetWindow-0.0.9-py3-none-any.whl
# Collecting mouseinfo (from pyautogui)
#   Using cached MouseInfo-0.1.3-py3-none-any.whl
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui)
#   Using cached PyRect-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow>=9.3.0 in c:\users\ea\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Collecting pyperclip (from mouseinfo->pyautogui)
#   Using cached pyperclip-1.8.2-py3-none-any.whl
# Installing collected packages: pytweening, pyrect, pyperclip, pymsgbox, pyscreeze, pygetwindow, mouseinfo, pyautogui
# Successfully installed mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.30 pytweening-1.0.7

# %%
import pyautogui
import pyperclip

# %%
#abrir uma nova aba no navegador (ctrl + t)
pyautogui.hotkey("ctrl", "t")

#digitar o endereço do gmail e dar um enter
pyperclip.copy("www.hotmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

time.sleep(5)

#clicar no botão escrever
pyautogui.click(x=171, y=180)


time.sleep(6)
#colocar e-mail do destinatário (tab)
 
pyperclip.copy("leticiabertolazi@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")


time.sleep(5)
#colocar o assunto 
pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")


#corpo do e-mail
time.sleep(5)
mensagem = f""" 

Prezada Leticia,

Segue as análises diárias dos últimos seis meses da ação {codigo}:

Cotação Máxima: R$ {round(maxima,2)}
Cotação Mínima: R$ {round(minima,2)}
Cotação Atual: R$ {round(atual,2)}

Qualquer dúvida , fico à disposição!

Estou utilizando Python para automatizar esse envio de analise e e-mail.


Mariana Bordignon

"""
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
time.sleep(10)

#clicar no botão enviar
pyautogui.click(x=355, y=261)
